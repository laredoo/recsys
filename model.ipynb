# %%
import pandas as pd

TRAIN_DATASET_PATH = "./dataset/2023_spotify_ds1.csv"
TEST_DATASET_PATH = "./dataset/2023_spotify_ds2.csv"
SONGS_DATASET_PATH = "./dataset/2023_spotify_songs.csv"

# %% [markdown]
# Input: list of songs the user likes
#
# Output: list of song recommendations

# %%
songs_dataset = pd.read_csv(SONGS_DATASET_PATH)

songs_dataset
# Out:
#             artist_name                                    track_name
# 0              Sam Hunt               Bottle It Up - Acoustic Mixtape
# 1          Ryan Gosling  City Of Stars - From "La La Land" Soundtrack
# 2           Knife Party                                       Bonfire
# 3     Avenged Sevenfold                         Welcome to the Family
# 4           Cheat Codes                                    Follow You
# ...                 ...                                           ...
# 6969         Pink Floyd                                       Hey You
# 6970          Lifehouse                                  Halfway Gone
# 6971             Eminem                               Won't Back Down
# 6972        Miley Cyrus                                           4x4
# 6973           San Holo                                       We Rise
#
# [6974 rows x 2 columns]

# %%
spotify_playlists_1 = pd.read_csv(TRAIN_DATASET_PATH).dropna()
spotify_playlists_2 = pd.read_csv(TEST_DATASET_PATH).dropna()

# %%
spotify_playlists = spotify_playlists_1.append(spotify_playlists_2)

# %%
playlist_groups_df = (
    spotify_playlists
    .groupby('pid')
    .agg(
        {
            'track_uri': list,
            'track_name': list
        }
    )
    .reset_index(drop=False)
)

playlist_groups_df
# Out:
#          pid                                          track_uri  \
# 0        115  [spotify:track:06iMqWThw4w8fTFyccvOwr, spotify...
# 1        124  [spotify:track:3ZAMtgYJFoHwJjFkhkXqKr, spotify...
# 2        161  [spotify:track:5sUlaoVcLPk2Wr695jp6dd, spotify...
# 3        362  [spotify:track:1VCHNbal0VtE2plMRzvoho, spotify...
# 4        403  [spotify:track:06iMqWThw4w8fTFyccvOwr, spotify...
# ...      ...                                                ...
# 2257  169750  [spotify:track:6ltPEsP4edATzvinHOzvk2, spotify...
# 2258  169886  [spotify:track:5dNGORzxFb5z3v7vSAFkTU, spotify...
# 2259  169931  [spotify:track:5dNGORzxFb5z3v7vSAFkTU, spotify...
# 2260  169955  [spotify:track:0iA1unTbTbDOWUSlbwJ1pS, spotify...
# 2261  169999  [spotify:track:6ltPEsP4edATzvinHOzvk2, spotify...
#
#                                              track_name
# 0     [Ride Wit Me, Red Solo Cup, Sweet Emotion, Buy...
# 1     [Dance (A$$) Remix, Weekend, Clique, Good Girl...
# 2     [Bartender, Just the Way You Are, Smack That -...
# 3     [Weekend, Misery, Die A Happy Man, The Only Ex...
# 4     [Ride Wit Me, Weekend, She Knows, Runaway, Bew...
# ...                                                 ...
# 2257  [Still D.R.E., OOOUUU, Still Here, Tuesday (fe...
# 2258  [Beachin', American Country Love Song, Who I A...
# 2259  [Beachin', American Country Love Song, It Don'...
# 2260  [It Don't Hurt Like It Used To, Fix, Hard To L...
# 2261  [Still D.R.E., Ride Wit Me, I Wanna Rock, Pour...
#
# [2262 rows x 3 columns]

# %% [markdown]
# # FPGrowth

# %%
from fpgrowth_py import fpgrowth

sample_df = playlist_groups_df
sample_df
# Out:
#          pid                                          track_uri  \
# 0        115  [spotify:track:06iMqWThw4w8fTFyccvOwr, spotify...
# 1        124  [spotify:track:3ZAMtgYJFoHwJjFkhkXqKr, spotify...
# 2        161  [spotify:track:5sUlaoVcLPk2Wr695jp6dd, spotify...
# 3        362  [spotify:track:1VCHNbal0VtE2plMRzvoho, spotify...
# 4        403  [spotify:track:06iMqWThw4w8fTFyccvOwr, spotify...
# ...      ...                                                ...
# 2257  169750  [spotify:track:6ltPEsP4edATzvinHOzvk2, spotify...
# 2258  169886  [spotify:track:5dNGORzxFb5z3v7vSAFkTU, spotify...
# 2259  169931  [spotify:track:5dNGORzxFb5z3v7vSAFkTU, spotify...
# 2260  169955  [spotify:track:0iA1unTbTbDOWUSlbwJ1pS, spotify...
# 2261  169999  [spotify:track:6ltPEsP4edATzvinHOzvk2, spotify...
#
#                                              track_name
# 0     [Ride Wit Me, Red Solo Cup, Sweet Emotion, Buy...
# 1     [Dance (A$$) Remix, Weekend, Clique, Good Girl...
# 2     [Bartender, Just the Way You Are, Smack That -...
# 3     [Weekend, Misery, Die A Happy Man, The Only Ex...
# 4     [Ride Wit Me, Weekend, She Knows, Runaway, Bew...
# ...                                                 ...
# 2257  [Still D.R.E., OOOUUU, Still Here, Tuesday (fe...
# 2258  [Beachin', American Country Love Song, Who I A...
# 2259  [Beachin', American Country Love Song, It Don'...
# 2260  [It Don't Hurt Like It Used To, Fix, Hard To L...
# 2261  [Still D.R.E., Ride Wit Me, I Wanna Rock, Pour...
#
# [2262 rows x 3 columns]

# %%
sample = sample_df.to_dict('list')['track_name']

# %%
freq_itemset_sample, rules_sample = fpgrowth(sample, minSupRatio=0.05, minConf=0.15)

# supratio = transaction / all_transactions
# confidence = consequent / (consequent U antecedent)

# %%
from typing import Dict, List

class Preprocess():
    def __init__(self, freqItemSet, rules):
        self.freqItemSet = freqItemSet
        self.rules = rules

    def preprocess_itemset(
        self, 
        sample_list: List = None
    ) -> Dict:

        result = [
            {
                'frequent_item_sets': list(item) 
            }
            
            for item in (self.freqItemSet if not sample_list else sample_list)
        ]

        return result
    
    def preprocess_rules(
        self,
        rules: List = None
    ):
        result = [
            {
                'antecedent': list(antecedent),
                'consequent': list(consequent),
                'confidence': confidence
            }

            for antecedent, consequent, confidence in (self.rules if not rules else rules)
        ]

        return result

# %%
pre_process_entity = Preprocess(freq_itemset_sample, rules_sample)

freq_itemset = pre_process_entity.preprocess_itemset()
rules = pre_process_entity.preprocess_rules()

# %%
rules_df = pd.DataFrame(rules)
freq_itemset_df = pd.DataFrame(freq_itemset)

# %%
rules_df
# Out:
#                           antecedent                     consequent  \
# 0                   [Crash And Burn]              [Night's On Fire]
# 1                  [Night's On Fire]               [Crash And Burn]
# 2                     [Lose My Mind]               [Crash And Burn]
# 3                   [Crash And Burn]                 [Lose My Mind]
# 4                 [I Love This Life]               [Crash And Burn]
# ...                              ...                            ...
# 30798                    [One Dance]  [Broccoli (feat. Lil Yachty)]
# 30799  [Broccoli (feat. Lil Yachty)]                       [Closer]
# 30800                       [Closer]  [Broccoli (feat. Lil Yachty)]
# 30801                      [T-Shirt]  [Broccoli (feat. Lil Yachty)]
# 30802  [Broccoli (feat. Lil Yachty)]                      [T-Shirt]
#
#        confidence
# 0        0.402715
# 1        0.760684
# 2        0.822581
# 3        0.461538
# 4        0.743802
# ...           ...
# 30798    0.514874
# 30799    0.339130
# 30800    0.320988
# 30801    0.347826
# 30802    0.382609
#
# [30803 rows x 3 columns]

# %%
song_name = 'Broccoli (feat. Lil Yachty)'

mask = freq_itemset_df['frequent_item_sets'].apply(lambda x: song_name in x)

filtered_df = freq_itemset_df[mask]

filtered_df
# Out:
#                                      frequent_item_sets
# 647   [Broccoli (feat. Lil Yachty), Cut It (feat. Yo...
# 809       [Broccoli (feat. Lil Yachty), Down In the DM]
# 812           [DEVASTATED, Broccoli (feat. Lil Yachty)]
# 838            [Broccoli (feat. Lil Yachty), Champions]
# 890               [Broccoli (feat. Lil Yachty), OOOUUU]
# ...                                                 ...
# 5252             [Broccoli (feat. Lil Yachty), HUMBLE.]
# 5256           [Broccoli (feat. Lil Yachty), One Dance]
# 5257                      [Broccoli (feat. Lil Yachty)]
# 5258              [Broccoli (feat. Lil Yachty), Closer]
# 5259             [T-Shirt, Broccoli (feat. Lil Yachty)]
#
# [444 rows x 1 columns]

# %%
song_name = 'Crash And Burn'

mask = rules_df['antecedent'].apply(lambda x: song_name in x)

filtered_df = rules_df[mask]

filtered_df
# Out:
#                                 antecedent  \
# 0                         [Crash And Burn]
# 3                         [Crash And Burn]
# 5                         [Crash And Burn]
# 16                        [Crash And Burn]
# 20                        [Crash And Burn]
# ...                                    ...
# 7124                      [Crash And Burn]
# 7127                      [Crash And Burn]
# 7129     [Die A Happy Man, Crash And Burn]
# 7131  [Crash And Burn, Leave The Night On]
# 7133                      [Crash And Burn]
#
#                                  consequent  confidence
# 0                         [Night's On Fire]    0.402715
# 3                            [Lose My Mind]    0.461538
# 5                        [I Love This Life]    0.407240
# 16                            [Wasted Time]    0.429864
# 20                      [Sleep Without You]    0.429864
# ...                                     ...         ...
# 7124                   [Leave The Night On]    0.678733
# 7127  [Die A Happy Man, Leave The Night On]    0.524887
# 7129                   [Leave The Night On]    0.711656
# 7131                      [Die A Happy Man]    0.773333
# 7133                      [Die A Happy Man]    0.737557
#
# [1012 rows x 3 columns]

# %%
filtered_df['consequent'].to_list()
# Out:
# [["Night's On Fire"],
#  ['Lose My Mind'],
#  ['I Love This Life'],
#  ['Wasted Time'],
#  ['Sleep Without You'],
#  ['Die A Happy Man', 'Confession'],
#  ['Confession'],
#  ['Die A Happy Man'],
#  ['Confession'],
#  ['Leave The Night On', 'Sippin’ On Fire'],
#  ['Sippin’ On Fire'],
#  ['Leave The Night On'],
#  ['Sippin’ On Fire'],
#  ['Gonna Wanna Tonight'],
#  ['Gonna Wanna Tonight', 'Die A Happy Man'],
#  ['Die A Happy Man'],
#  ['Gonna Wanna Tonight'],
#  ["Burnin' It Down"],
#  ['Drunk On Your Love'],
#  ['Ready Set Roll', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['Ready Set Roll'],
#  ['Ready Set Roll'],
#  ['Die A Happy Man', 'Backroad Song'],
#  ['Backroad Song'],
#  ['Die A Happy Man'],
#  ['Backroad Song'],
#  ["Whatever She's Got"],
#  ["Whatever She's Got", 'It Goes Like This'],
#  ['It Goes Like This'],
#  ["Whatever She's Got"],
#  ['American Country Love Song'],
#  ["Where It's At"],
#  ['Hurricane'],
#  ['How Country Feels'],
#  ['Beat Of The Music'],
#  ['Sun Daze', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['Sun Daze'],
#  ['Sun Daze'],
#  ['Drinking class'],
#  ['Humble And Kind'],
#  ['Humble And Kind', 'Die A Happy Man'],
#  ['Die A Happy Man'],
#  ['Humble And Kind'],
#  ['Sangria'],
#  ['Die A Happy Man', 'Sangria'],
#  ['Sangria'],
#  ['Die A Happy Man'],
#  ['Get Me Some Of That', 'Die A Happy Man'],
#  ['Die A Happy Man'],
#  ['Get Me Some Of That'],
#  ['Get Me Some Of That', 'It Goes Like This', 'Leave The Night On'],
#  ['It Goes Like This', 'Leave The Night On'],
#  ['Get Me Some Of That', 'Leave The Night On'],
#  ['Get Me Some Of That', 'It Goes Like This'],
#  ['Leave The Night On'],
#  ['It Goes Like This'],
#  ['Get Me Some Of That'],
#  ['Get Me Some Of That', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['Get Me Some Of That'],
#  ['Get Me Some Of That'],
#  ['Get Me Some Of That', 'It Goes Like This'],
#  ['It Goes Like This'],
#  ['Get Me Some Of That'],
#  ['House Party', 'Kick The Dust Up'],
#  ['Kick The Dust Up'],
#  ['House Party'],
#  ['Die A Happy Man', 'Kick The Dust Up'],
#  ['Kick The Dust Up'],
#  ['Die A Happy Man'],
#  ['Kick The Dust Up'],
#  ['Loving You Easy', 'Die A Happy Man'],
#  ['Die A Happy Man'],
#  ['Loving You Easy'],
#  ['Loving You Easy'],
#  ['Love You Like That', 'Stay A Little Longer'],
#  ['Stay A Little Longer'],
#  ['Love You Like That'],
#  ['Love You Like That', 'Die A Happy Man', 'H.O.L.Y.'],
#  ['Die A Happy Man', 'H.O.L.Y.'],
#  ['Love You Like That', 'H.O.L.Y.'],
#  ['Love You Like That', 'Die A Happy Man'],
#  ['H.O.L.Y.'],
#  ['Die A Happy Man'],
#  ['Love You Like That'],
#  ['Love You Like That', 'H.O.L.Y.'],
#  ['H.O.L.Y.'],
#  ['Love You Like That'],
#  ['Love You Like That', 'House Party'],
#  ['House Party'],
#  ['Love You Like That'],
#  ['Love You Like That', 'Play It Again', 'Leave The Night On'],
#  ['Leave The Night On', 'Play It Again'],
#  ['Love You Like That', 'Play It Again'],
#  ['Love You Like That', 'Leave The Night On'],
#  ['Play It Again'],
#  ['Leave The Night On'],
#  ['Love You Like That'],
#  ['Love You Like That', 'Play It Again'],
#  ['Play It Again'],
#  ['Love You Like That'],
#  ['Love You Like That', 'It Goes Like This', 'Leave The Night On'],
#  ['It Goes Like This', 'Leave The Night On'],
#  ['Love You Like That', 'Leave The Night On'],
#  ['Love You Like That', 'It Goes Like This'],
#  ['Leave The Night On'],
#  ['It Goes Like This'],
#  ['Love You Like That'],
#  ['Love You Like That', 'It Goes Like This', 'Die A Happy Man'],
#  ['Die A Happy Man', 'It Goes Like This'],
#  ['Love You Like That', 'Die A Happy Man'],
#  ['Love You Like That', 'It Goes Like This'],
#  ['Die A Happy Man'],
#  ['It Goes Like This'],
#  ['Love You Like That'],
#  ['Love You Like That', 'It Goes Like This'],
#  ['It Goes Like This'],
#  ['Love You Like That'],
#  ['Love You Like That', 'Die A Happy Man'],
#  ['Die A Happy Man'],
#  ['Love You Like That'],
#  ['Love You Like That', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['Love You Like That'],
#  ['Love You Like That'],
#  ['Leave The Night On', 'Sunshine & Whiskey'],
#  ['Sunshine & Whiskey'],
#  ['Leave The Night On'],
#  ['Sunshine & Whiskey'],
#  ['May We All'],
#  ['H.O.L.Y.', "I'm Comin' Over"],
#  ["I'm Comin' Over"],
#  ['H.O.L.Y.'],
#  ['Die A Happy Man', 'It Goes Like This', "I'm Comin' Over"],
#  ['It Goes Like This', "I'm Comin' Over"],
#  ['Die A Happy Man', "I'm Comin' Over"],
#  ['Die A Happy Man', 'It Goes Like This'],
#  ["I'm Comin' Over"],
#  ['It Goes Like This'],
#  ['Die A Happy Man'],
#  ['It Goes Like This', "I'm Comin' Over"],
#  ["I'm Comin' Over"],
#  ['It Goes Like This'],
#  ['Die A Happy Man', "I'm Comin' Over"],
#  ["I'm Comin' Over"],
#  ['Die A Happy Man'],
#  ["I'm Comin' Over"],
#  ['Die A Happy Man', 'John Cougar, John Deere, John 3:16'],
#  ['John Cougar, John Deere, John 3:16'],
#  ['Die A Happy Man'],
#  ['John Cougar, John Deere, John 3:16'],
#  ['Talladega'],
#  ["I Don't Dance"],
#  ['Dirt Road Anthem'],
#  ['Make Me Wanna', 'Play It Again'],
#  ['Play It Again'],
#  ['Make Me Wanna'],
#  ['Make Me Wanna', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['Make Me Wanna'],
#  ['Die A Happy Man', 'Make Me Wanna'],
#  ['Make Me Wanna'],
#  ['Die A Happy Man'],
#  ['Make Me Wanna', 'It Goes Like This'],
#  ['It Goes Like This'],
#  ['Make Me Wanna'],
#  ['Make Me Wanna'],
#  ['Head Over Boots'],
#  ['It Goes Like This', 'Anything Goes'],
#  ['Anything Goes'],
#  ['It Goes Like This'],
#  ['H.O.L.Y.', 'Anything Goes'],
#  ['Anything Goes'],
#  ['H.O.L.Y.'],
#  ['Anything Goes', 'House Party'],
#  ['House Party'],
#  ['Anything Goes'],
#  ['Anything Goes', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['Anything Goes'],
#  ['Die A Happy Man', 'Anything Goes'],
#  ['Anything Goes'],
#  ['Die A Happy Man'],
#  ['Anything Goes'],
#  ['Get Your Shine On'],
#  ['Dirt', 'It Goes Like This'],
#  ['It Goes Like This'],
#  ['Dirt'],
#  ['Die A Happy Man', 'Dirt', 'It Goes Like This'],
#  ['Dirt', 'It Goes Like This'],
#  ['Die A Happy Man', 'It Goes Like This'],
#  ['Die A Happy Man', 'Dirt'],
#  ['It Goes Like This'],
#  ['Dirt'],
#  ['Die A Happy Man'],
#  ['Die A Happy Man', 'Dirt'],
#  ['Dirt'],
#  ['Die A Happy Man'],
#  ['Dirt', 'Play It Again', 'Leave The Night On'],
#  ['Leave The Night On', 'Play It Again'],
#  ['Dirt', 'Play It Again'],
#  ['Dirt', 'Leave The Night On'],
#  ['Play It Again'],
#  ['Leave The Night On'],
#  ['Dirt'],
#  ['Dirt', 'Play It Again'],
#  ['Play It Again'],
#  ['Dirt'],
#  ['Dirt', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['Dirt'],
#  ['Dirt', 'This Is How We Roll'],
#  ['This Is How We Roll'],
#  ['Dirt'],
#  ['Dirt'],
#  ['Leave The Night On', 'I Like The Sound Of That'],
#  ['I Like The Sound Of That'],
#  ['Leave The Night On'],
#  ['Die A Happy Man', 'H.O.L.Y.', 'I Like The Sound Of That'],
#  ['H.O.L.Y.', 'I Like The Sound Of That'],
#  ['Die A Happy Man', 'I Like The Sound Of That'],
#  ['Die A Happy Man', 'H.O.L.Y.'],
#  ['I Like The Sound Of That'],
#  ['H.O.L.Y.'],
#  ['Die A Happy Man'],
#  ['H.O.L.Y.', 'I Like The Sound Of That'],
#  ['I Like The Sound Of That'],
#  ['H.O.L.Y.'],
#  ['T-Shirt', 'Die A Happy Man', 'I Like The Sound Of That'],
#  ['Die A Happy Man', 'I Like The Sound Of That'],
#  ['T-Shirt', 'I Like The Sound Of That'],
#  ['T-Shirt', 'Die A Happy Man'],
#  ['I Like The Sound Of That'],
#  ['Die A Happy Man'],
#  ['T-Shirt'],
#  ['T-Shirt', 'I Like The Sound Of That'],
#  ['I Like The Sound Of That'],
#  ['T-Shirt'],
#  ['I Like The Sound Of That'],
#  ['Die A Happy Man', 'I Like The Sound Of That'],
#  ['I Like The Sound Of That'],
#  ['Die A Happy Man'],
#  ['Round Here'],
#  ['Round Here', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['Round Here'],
#  ['Break Up with Him', 'Play It Again'],
#  ['Play It Again'],
#  ['Break Up with Him'],
#  ['Break Up with Him', 'H.O.L.Y.'],
#  ['H.O.L.Y.'],
#  ['Break Up with Him'],
#  ['It Goes Like This', 'Break Up with Him'],
#  ['Break Up with Him'],
#  ['It Goes Like This'],
#  ['T-Shirt', 'Break Up with Him'],
#  ['Break Up with Him'],
#  ['T-Shirt'],
#  ['Break Up with Him', 'House Party'],
#  ['House Party'],
#  ['Break Up with Him'],
#  ['Break Up with Him', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['Break Up with Him'],
#  ['Die A Happy Man', 'Break Up with Him'],
#  ['Break Up with Him'],
#  ['Die A Happy Man'],
#  ['Break Up with Him'],
#  ['Stay A Little Longer', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['Stay A Little Longer'],
#  ['Die A Happy Man', 'Stay A Little Longer', 'H.O.L.Y.'],
#  ['Stay A Little Longer', 'H.O.L.Y.'],
#  ['Die A Happy Man', 'Stay A Little Longer'],
#  ['Die A Happy Man', 'H.O.L.Y.'],
#  ['Stay A Little Longer'],
#  ['H.O.L.Y.'],
#  ['Die A Happy Man'],
#  ['Stay A Little Longer', 'H.O.L.Y.'],
#  ['Stay A Little Longer'],
#  ['H.O.L.Y.'],
#  ['Die A Happy Man', 'It Goes Like This', 'Stay A Little Longer'],
#  ['It Goes Like This', 'Stay A Little Longer'],
#  ['Die A Happy Man', 'Stay A Little Longer'],
#  ['Die A Happy Man', 'It Goes Like This'],
#  ['Stay A Little Longer'],
#  ['It Goes Like This'],
#  ['Die A Happy Man'],
#  ['It Goes Like This', 'Stay A Little Longer'],
#  ['Stay A Little Longer'],
#  ['It Goes Like This'],
#  ['T-Shirt', 'Die A Happy Man', 'Stay A Little Longer'],
#  ['Die A Happy Man', 'Stay A Little Longer'],
#  ['T-Shirt', 'Stay A Little Longer'],
#  ['T-Shirt', 'Die A Happy Man'],
#  ['Stay A Little Longer'],
#  ['Die A Happy Man'],
#  ['T-Shirt'],
#  ['T-Shirt', 'Stay A Little Longer'],
#  ['Stay A Little Longer'],
#  ['T-Shirt'],
#  ['Die A Happy Man', 'Stay A Little Longer'],
#  ['Stay A Little Longer'],
#  ['Die A Happy Man'],
#  ['Stay A Little Longer'],
#  ['Snapback', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['Snapback'],
#  ['Die A Happy Man', 'Snapback', 'H.O.L.Y.'],
#  ['Snapback', 'H.O.L.Y.'],
#  ['Die A Happy Man', 'Snapback'],
#  ['Die A Happy Man', 'H.O.L.Y.'],
#  ['Snapback'],
#  ['H.O.L.Y.'],
#  ['Die A Happy Man'],
#  ['Snapback', 'H.O.L.Y.'],
#  ['Snapback'],
#  ['H.O.L.Y.'],
#  ['Die A Happy Man', 'Snapback', 'Somewhere On A Beach'],
#  ['Snapback', 'Somewhere On A Beach'],
#  ['Die A Happy Man', 'Somewhere On A Beach'],
#  ['Die A Happy Man', 'Snapback'],
#  ['Somewhere On A Beach'],
#  ['Snapback'],
#  ['Die A Happy Man'],
#  ['Snapback', 'Somewhere On A Beach'],
#  ['Somewhere On A Beach'],
#  ['Snapback'],
#  ['Snapback', 'Body Like A Back Road'],
#  ['Body Like A Back Road'],
#  ['Snapback'],
#  ['T-Shirt', 'Die A Happy Man', 'Snapback'],
#  ['Die A Happy Man', 'Snapback'],
#  ['T-Shirt', 'Snapback'],
#  ['T-Shirt', 'Die A Happy Man'],
#  ['Snapback'],
#  ['Die A Happy Man'],
#  ['T-Shirt'],
#  ['Die A Happy Man', 'Snapback'],
#  ['Snapback'],
#  ['Die A Happy Man'],
#  ['Snapback'],
#  ['T-Shirt', 'Snapback'],
#  ['Snapback'],
#  ['T-Shirt'],
#  ['Homegrown', 'Play It Again', 'Leave The Night On'],
#  ['Leave The Night On', 'Play It Again'],
#  ['Homegrown', 'Play It Again'],
#  ['Homegrown', 'Leave The Night On'],
#  ['Play It Again'],
#  ['Leave The Night On'],
#  ['Homegrown'],
#  ['Homegrown', 'Play It Again'],
#  ['Play It Again'],
#  ['Homegrown'],
#  ['Homegrown', 'House Party'],
#  ['House Party'],
#  ['Homegrown'],
#  ['Die A Happy Man', 'Homegrown'],
#  ['Homegrown'],
#  ['Die A Happy Man'],
#  ['Homegrown', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['Homegrown'],
#  ['Homegrown'],
#  ['Make You Miss Me'],
#  ['Make You Miss Me', 'H.O.L.Y.'],
#  ['H.O.L.Y.'],
#  ['Make You Miss Me'],
#  ['Die A Happy Man', 'Make You Miss Me', 'H.O.L.Y.'],
#  ['Make You Miss Me', 'H.O.L.Y.'],
#  ['Die A Happy Man', 'H.O.L.Y.'],
#  ['Die A Happy Man', 'Make You Miss Me'],
#  ['H.O.L.Y.'],
#  ['Make You Miss Me'],
#  ['Die A Happy Man'],
#  ['Die A Happy Man', 'Make You Miss Me'],
#  ['Make You Miss Me'],
#  ['Die A Happy Man'],
#  ['T-Shirt', 'Make You Miss Me'],
#  ['Make You Miss Me'],
#  ['T-Shirt'],
#  ['Drunk On A Plane', 'Die A Happy Man'],
#  ['Die A Happy Man'],
#  ['Drunk On A Plane'],
#  ['Drunk On A Plane', 'Play It Again'],
#  ['Play It Again'],
#  ['Drunk On A Plane'],
#  ['Drunk On A Plane', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['Drunk On A Plane'],
#  ['Drunk On A Plane'],
#  ['American Kids'],
#  ['Take Your Time'],
#  ['Die A Happy Man', 'Take Your Time'],
#  ['Take Your Time'],
#  ['Die A Happy Man'],
#  ['Take Your Time', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['Take Your Time'],
#  ['It Goes Like This', "Don't It"],
#  ["Don't It"],
#  ['It Goes Like This'],
#  ["Don't It", 'House Party'],
#  ["Don't It"],
#  ['House Party'],
#  ['Die A Happy Man', "Don't It"],
#  ["Don't It"],
#  ['Die A Happy Man'],
#  ["Don't It", 'Leave The Night On'],
#  ["Don't It"],
#  ['Leave The Night On'],
#  ["Don't It"],
#  ['Die A Happy Man', "Runnin' Outta Moonlight"],
#  ["Runnin' Outta Moonlight"],
#  ['Die A Happy Man'],
#  ['Die A Happy Man', 'It Goes Like This', "Runnin' Outta Moonlight"],
#  ['It Goes Like This', "Runnin' Outta Moonlight"],
#  ['Die A Happy Man', "Runnin' Outta Moonlight"],
#  ['Die A Happy Man', 'It Goes Like This'],
#  ["Runnin' Outta Moonlight"],
#  ['It Goes Like This'],
#  ['Die A Happy Man'],
#  ["Runnin' Outta Moonlight"],
#  ['Leave The Night On', "Runnin' Outta Moonlight"],
#  ["Runnin' Outta Moonlight"],
#  ['Leave The Night On'],
#  ['It Goes Like This', 'Leave The Night On', "Runnin' Outta Moonlight"],
#  ['Leave The Night On', "Runnin' Outta Moonlight"],
#  ['It Goes Like This', "Runnin' Outta Moonlight"],
#  ['It Goes Like This', 'Leave The Night On'],
#  ["Runnin' Outta Moonlight"],
#  ['Leave The Night On'],
#  ['It Goes Like This'],
#  ['Leave The Night On', 'Play It Again', "Runnin' Outta Moonlight"],
#  ['Leave The Night On', "Runnin' Outta Moonlight"],
#  ['Play It Again', "Runnin' Outta Moonlight"],
#  ['Leave The Night On', 'Play It Again'],
#  ["Runnin' Outta Moonlight"],
#  ['Leave The Night On'],
#  ['Play It Again'],
#  ['Play It Again', "Runnin' Outta Moonlight"],
#  ["Runnin' Outta Moonlight"],
#  ['Play It Again'],
#  ['It Goes Like This', 'Play It Again', "Runnin' Outta Moonlight"],
#  ['Play It Again', "Runnin' Outta Moonlight"],
#  ['It Goes Like This', "Runnin' Outta Moonlight"],
#  ['It Goes Like This', 'Play It Again'],
#  ["Runnin' Outta Moonlight"],
#  ['Play It Again'],
#  ['It Goes Like This'],
#  ['It Goes Like This', "Runnin' Outta Moonlight"],
#  ["Runnin' Outta Moonlight"],
#  ['It Goes Like This'],
#  ['Leave The Night On', 'Somewhere On A Beach'],
#  ['Somewhere On A Beach'],
#  ['Leave The Night On'],
#  ['It Goes Like This', 'Somewhere On A Beach'],
#  ['Somewhere On A Beach'],
#  ['It Goes Like This'],
#  ['Die A Happy Man', 'It Goes Like This', 'Somewhere On A Beach'],
#  ['It Goes Like This', 'Somewhere On A Beach'],
#  ['Die A Happy Man', 'Somewhere On A Beach'],
#  ['Die A Happy Man', 'It Goes Like This'],
#  ['Somewhere On A Beach'],
#  ['It Goes Like This'],
#  ['Die A Happy Man'],
#  ['Die A Happy Man', 'House Party', 'Somewhere On A Beach'],
#  ['House Party', 'Somewhere On A Beach'],
#  ['Die A Happy Man', 'Somewhere On A Beach'],
#  ['Die A Happy Man', 'House Party'],
#  ['Somewhere On A Beach'],
#  ['House Party'],
#  ['Die A Happy Man'],
#  ['House Party', 'Somewhere On A Beach'],
#  ['Somewhere On A Beach'],
#  ['House Party'],
#  ['H.O.L.Y.', 'Body Like A Back Road', 'Somewhere On A Beach'],
#  ['Body Like A Back Road', 'Somewhere On A Beach'],
#  ['H.O.L.Y.', 'Somewhere On A Beach'],
#  ['H.O.L.Y.', 'Body Like A Back Road'],
#  ['Somewhere On A Beach'],
#  ['Body Like A Back Road'],
#  ['H.O.L.Y.'],
#  ['Body Like A Back Road', 'Somewhere On A Beach'],
#  ['Somewhere On A Beach'],
#  ['Body Like A Back Road'],
#  ['Die A Happy Man', 'Body Like A Back Road', 'Somewhere On A Beach'],
#  ['Body Like A Back Road', 'Somewhere On A Beach'],
#  ['Die A Happy Man', 'Somewhere On A Beach'],
#  ['Die A Happy Man', 'Body Like A Back Road'],
#  ['Somewhere On A Beach'],
#  ['Body Like A Back Road'],
#  ['Die A Happy Man'],
#  ['Die A Happy Man', 'H.O.L.Y.', 'Somewhere On A Beach'],
#  ['H.O.L.Y.', 'Somewhere On A Beach'],
#  ['Die A Happy Man', 'Somewhere On A Beach'],
#  ['Die A Happy Man', 'H.O.L.Y.'],
#  ['Somewhere On A Beach'],
#  ['H.O.L.Y.'],
#  ['Die A Happy Man'],
#  ['H.O.L.Y.', 'Somewhere On A Beach'],
#  ['Somewhere On A Beach'],
#  ['H.O.L.Y.'],
#  ['T-Shirt', 'Somewhere On A Beach'],
#  ['Somewhere On A Beach'],
#  ['T-Shirt'],
#  ['T-Shirt', 'Die A Happy Man', 'Somewhere On A Beach'],
#  ['Die A Happy Man', 'Somewhere On A Beach'],
#  ['T-Shirt', 'Somewhere On A Beach'],
#  ['T-Shirt', 'Die A Happy Man'],
#  ['Somewhere On A Beach'],
#  ['Die A Happy Man'],
#  ['T-Shirt'],
#  ['Somewhere On A Beach'],
#  ['Die A Happy Man', 'Somewhere On A Beach'],
#  ['Somewhere On A Beach'],
#  ['Die A Happy Man'],
#  ['Knee Deep (feat. Jimmy Buffett)'],
#  ['Springsteen', 'Die A Happy Man', 'It Goes Like This'],
#  ['Die A Happy Man', 'It Goes Like This'],
#  ['Springsteen', 'It Goes Like This'],
#  ['Springsteen', 'Die A Happy Man'],
#  ['It Goes Like This'],
#  ['Die A Happy Man'],
#  ['Springsteen'],
#  ['Springsteen', 'It Goes Like This'],
#  ['It Goes Like This'],
#  ['Springsteen'],
#  ['Springsteen', 'Die A Happy Man'],
#  ['Die A Happy Man'],
#  ['Springsteen'],
#  ['Springsteen', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['Springsteen'],
#  ['Springsteen', 'Leave The Night On', 'Play It Again'],
#  ['Leave The Night On', 'Play It Again'],
#  ['Springsteen', 'Leave The Night On'],
#  ['Springsteen', 'Play It Again'],
#  ['Leave The Night On'],
#  ['Play It Again'],
#  ['Springsteen'],
#  ['Springsteen'],
#  ['Springsteen', 'Play It Again'],
#  ['Play It Again'],
#  ['Springsteen'],
#  ['It Goes Like This', "That's My Kind Of Night"],
#  ["That's My Kind Of Night"],
#  ['It Goes Like This'],
#  ['Die A Happy Man', "That's My Kind Of Night"],
#  ["That's My Kind Of Night"],
#  ['Die A Happy Man'],
#  ["That's My Kind Of Night"],
#  ['Leave The Night On', "That's My Kind Of Night"],
#  ["That's My Kind Of Night"],
#  ['Leave The Night On'],
#  ['Leave The Night On', 'Play It Again', "That's My Kind Of Night"],
#  ['Leave The Night On', "That's My Kind Of Night"],
#  ['Play It Again', "That's My Kind Of Night"],
#  ['Leave The Night On', 'Play It Again'],
#  ["That's My Kind Of Night"],
#  ['Leave The Night On'],
#  ['Play It Again'],
#  ['Play It Again', "That's My Kind Of Night"],
#  ["That's My Kind Of Night"],
#  ['Play It Again'],
#  ['Barefoot Blue Jean Night', 'It Goes Like This'],
#  ['It Goes Like This'],
#  ['Barefoot Blue Jean Night'],
#  ['Barefoot Blue Jean Night', 'Die A Happy Man'],
#  ['Die A Happy Man'],
#  ['Barefoot Blue Jean Night'],
#  ['Barefoot Blue Jean Night', 'Play It Again'],
#  ['Play It Again'],
#  ['Barefoot Blue Jean Night'],
#  ['Barefoot Blue Jean Night'],
#  ['Barefoot Blue Jean Night', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['Barefoot Blue Jean Night'],
#  ['Die A Happy Man', 'It Goes Like This', 'Body Like A Back Road'],
#  ['It Goes Like This', 'Body Like A Back Road'],
#  ['Die A Happy Man', 'Body Like A Back Road'],
#  ['Die A Happy Man', 'It Goes Like This'],
#  ['Body Like A Back Road'],
#  ['It Goes Like This'],
#  ['Die A Happy Man'],
#  ['It Goes Like This', 'Body Like A Back Road'],
#  ['Body Like A Back Road'],
#  ['It Goes Like This'],
#  ['It Goes Like This', 'H.O.L.Y.'],
#  ['H.O.L.Y.'],
#  ['It Goes Like This'],
#  ['Die A Happy Man', 'It Goes Like This', 'H.O.L.Y.'],
#  ['It Goes Like This', 'H.O.L.Y.'],
#  ['Die A Happy Man', 'H.O.L.Y.'],
#  ['Die A Happy Man', 'It Goes Like This'],
#  ['H.O.L.Y.'],
#  ['It Goes Like This'],
#  ['Die A Happy Man'],
#  ['It Goes Like This', 'House Party', 'Leave The Night On'],
#  ['Leave The Night On', 'House Party'],
#  ['It Goes Like This', 'House Party'],
#  ['It Goes Like This', 'Leave The Night On'],
#  ['House Party'],
#  ['Leave The Night On'],
#  ['It Goes Like This'],
#  ['Die A Happy Man', 'It Goes Like This', 'House Party'],
#  ['It Goes Like This', 'House Party'],
#  ['Die A Happy Man', 'House Party'],
#  ['Die A Happy Man', 'It Goes Like This'],
#  ['House Party'],
#  ['It Goes Like This'],
#  ['Die A Happy Man'],
#  ['It Goes Like This', 'House Party'],
#  ['House Party'],
#  ['It Goes Like This'],
#  ['T-Shirt', 'Die A Happy Man', 'It Goes Like This'],
#  ['Die A Happy Man', 'It Goes Like This'],
#  ['T-Shirt', 'It Goes Like This'],
#  ['T-Shirt', 'Die A Happy Man'],
#  ['It Goes Like This'],
#  ['Die A Happy Man'],
#  ['T-Shirt'],
#  ['T-Shirt', 'It Goes Like This'],
#  ['It Goes Like This'],
#  ['T-Shirt'],
#  ['Die A Happy Man', 'It Goes Like This', 'This Is How We Roll'],
#  ['This Is How We Roll', 'It Goes Like This'],
#  ['Die A Happy Man', 'This Is How We Roll'],
#  ['Die A Happy Man', 'It Goes Like This'],
#  ['This Is How We Roll'],
#  ['It Goes Like This'],
#  ['Die A Happy Man'],
#  ['It Goes Like This', 'Play It Again', 'This Is How We Roll'],
#  ['This Is How We Roll', 'Play It Again'],
#  ['This Is How We Roll', 'It Goes Like This'],
#  ['It Goes Like This', 'Play It Again'],
#  ['This Is How We Roll'],
#  ['Play It Again'],
#  ['It Goes Like This'],
#  ['Leave The Night On',
#   'This Is How We Roll',
#   'It Goes Like This',
#   'Play It Again'],
#  ['This Is How We Roll', 'Leave The Night On', 'It Goes Like This'],
#  ['This Is How We Roll', 'Leave The Night On', 'Play It Again'],
#  ['This Is How We Roll', 'It Goes Like This', 'Play It Again'],
#  ['It Goes Like This', 'Leave The Night On', 'Play It Again'],
#  ['This Is How We Roll', 'Leave The Night On'],
#  ['This Is How We Roll', 'It Goes Like This'],
#  ['It Goes Like This', 'Leave The Night On'],
#  ['This Is How We Roll', 'Play It Again'],
#  ['Leave The Night On', 'Play It Again'],
#  ['It Goes Like This', 'Play It Again'],
#  ['This Is How We Roll'],
#  ['Leave The Night On'],
#  ['It Goes Like This'],
#  ['Play It Again'],
#  ['It Goes Like This', 'This Is How We Roll'],
#  ['This Is How We Roll'],
#  ['It Goes Like This'],
#  ['It Goes Like This', 'Leave The Night On', 'This Is How We Roll'],
#  ['This Is How We Roll', 'Leave The Night On'],
#  ['This Is How We Roll', 'It Goes Like This'],
#  ['It Goes Like This', 'Leave The Night On'],
#  ['This Is How We Roll'],
#  ['Leave The Night On'],
#  ['It Goes Like This'],
#  ['Die A Happy Man',
#   'It Goes Like This',
#   'Leave The Night On',
#   'Play It Again'],
#  ['Die A Happy Man', 'It Goes Like This', 'Leave The Night On'],
#  ['Die A Happy Man', 'Leave The Night On', 'Play It Again'],
#  ['Die A Happy Man', 'It Goes Like This', 'Play It Again'],
#  ['It Goes Like This', 'Leave The Night On', 'Play It Again'],
#  ['Die A Happy Man', 'Leave The Night On'],
#  ['Die A Happy Man', 'It Goes Like This'],
#  ['It Goes Like This', 'Leave The Night On'],
#  ['Die A Happy Man', 'Play It Again'],
#  ['Leave The Night On', 'Play It Again'],
#  ['It Goes Like This', 'Play It Again'],
#  ['Die A Happy Man'],
#  ['Leave The Night On'],
#  ['It Goes Like This'],
#  ['Play It Again'],
#  ['Die A Happy Man', 'It Goes Like This', 'Play It Again'],
#  ['It Goes Like This', 'Play It Again'],
#  ['Die A Happy Man', 'Play It Again'],
#  ['Die A Happy Man', 'It Goes Like This'],
#  ['Play It Again'],
#  ['It Goes Like This'],
#  ['Die A Happy Man'],
#  ['It Goes Like This', 'Play It Again', 'Leave The Night On'],
#  ['Leave The Night On', 'Play It Again'],
#  ['It Goes Like This', 'Play It Again'],
#  ['It Goes Like This', 'Leave The Night On'],
#  ['Play It Again'],
#  ['Leave The Night On'],
#  ['It Goes Like This'],
#  ['It Goes Like This', 'Play It Again'],
#  ['Play It Again'],
#  ['It Goes Like This'],
#  ['Die A Happy Man', 'It Goes Like This', 'Leave The Night On'],
#  ['It Goes Like This', 'Leave The Night On'],
#  ['Die A Happy Man', 'Leave The Night On'],
#  ['Die A Happy Man', 'It Goes Like This'],
#  ['Leave The Night On'],
#  ['It Goes Like This'],
#  ['Die A Happy Man'],
#  ['It Goes Like This', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['It Goes Like This'],
#  ['Die A Happy Man', 'It Goes Like This'],
#  ['It Goes Like This'],
#  ['Die A Happy Man'],
#  ['It Goes Like This'],
#  ['T-Shirt', 'Break Up In A Small Town'],
#  ['Break Up In A Small Town'],
#  ['T-Shirt'],
#  ['T-Shirt', 'Break Up In A Small Town', 'Die A Happy Man'],
#  ['Die A Happy Man', 'Break Up In A Small Town'],
#  ['T-Shirt', 'Die A Happy Man'],
#  ['T-Shirt', 'Break Up In A Small Town'],
#  ['Die A Happy Man'],
#  ['Break Up In A Small Town'],
#  ['T-Shirt'],
#  ['Break Up In A Small Town', 'H.O.L.Y.'],
#  ['H.O.L.Y.'],
#  ['Break Up In A Small Town'],
#  ['Break Up In A Small Town', 'Die A Happy Man', 'H.O.L.Y.'],
#  ['Die A Happy Man', 'H.O.L.Y.'],
#  ['Break Up In A Small Town', 'H.O.L.Y.'],
#  ['Die A Happy Man', 'Break Up In A Small Town'],
#  ['H.O.L.Y.'],
#  ['Die A Happy Man'],
#  ['Break Up In A Small Town'],
#  ['Break Up In A Small Town', 'Play It Again'],
#  ['Play It Again'],
#  ['Break Up In A Small Town'],
#  ['Break Up In A Small Town'],
#  ['Break Up In A Small Town', 'House Party'],
#  ['House Party'],
#  ['Break Up In A Small Town'],
#  ['Break Up In A Small Town', 'Die A Happy Man', 'House Party'],
#  ['Die A Happy Man', 'House Party'],
#  ['Break Up In A Small Town', 'House Party'],
#  ['Die A Happy Man', 'Break Up In A Small Town'],
#  ['House Party'],
#  ['Die A Happy Man'],
#  ['Break Up In A Small Town'],
#  ['Break Up In A Small Town', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['Break Up In A Small Town'],
#  ['Break Up In A Small Town', 'Die A Happy Man', 'Leave The Night On'],
#  ['Die A Happy Man', 'Leave The Night On'],
#  ['Break Up In A Small Town', 'Leave The Night On'],
#  ['Die A Happy Man', 'Break Up In A Small Town'],
#  ['Leave The Night On'],
#  ['Die A Happy Man'],
#  ['Break Up In A Small Town'],
#  ['Break Up In A Small Town', 'Die A Happy Man'],
#  ['Die A Happy Man'],
#  ['Break Up In A Small Town'],
#  ['Cruise'],
#  ['Cruise', 'Leave The Night On'],
#  ['Cruise'],
#  ['Leave The Night On'],
#  ['Wagon Wheel', 'Die A Happy Man'],
#  ['Die A Happy Man'],
#  ['Wagon Wheel'],
#  ['Wagon Wheel', 'House Party'],
#  ['House Party'],
#  ['Wagon Wheel'],
#  ['Wagon Wheel', 'Play It Again'],
#  ['Play It Again'],
#  ['Wagon Wheel'],
#  ['Wagon Wheel'],
#  ['Wagon Wheel', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['Wagon Wheel'],
#  ['Die A Happy Man',
#   'This Is How We Roll',
#   'Leave The Night On',
#   'Play It Again'],
#  ['Die A Happy Man', 'This Is How We Roll', 'Leave The Night On'],
#  ['Die A Happy Man', 'This Is How We Roll', 'Play It Again'],
#  ['Die A Happy Man', 'Leave The Night On', 'Play It Again'],
#  ['This Is How We Roll', 'Leave The Night On', 'Play It Again'],
#  ['Die A Happy Man', 'This Is How We Roll'],
#  ['Die A Happy Man', 'Leave The Night On'],
#  ['This Is How We Roll', 'Leave The Night On'],
#  ['Die A Happy Man', 'Play It Again'],
#  ['This Is How We Roll', 'Play It Again'],
#  ['Leave The Night On', 'Play It Again'],
#  ['Die A Happy Man'],
#  ['This Is How We Roll'],
#  ['Leave The Night On'],
#  ['Play It Again'],
#  ['Die A Happy Man', 'This Is How We Roll', 'Leave The Night On'],
#  ['This Is How We Roll', 'Leave The Night On'],
#  ['Die A Happy Man', 'Leave The Night On'],
#  ['Die A Happy Man', 'This Is How We Roll'],
#  ['Leave The Night On'],
#  ['This Is How We Roll'],
#  ['Die A Happy Man'],
#  ['Die A Happy Man', 'This Is How We Roll', 'Play It Again'],
#  ['This Is How We Roll', 'Play It Again'],
#  ['Die A Happy Man', 'Play It Again'],
#  ['Die A Happy Man', 'This Is How We Roll'],
#  ['Play It Again'],
#  ['This Is How We Roll'],
#  ['Die A Happy Man'],
#  ['Die A Happy Man', 'This Is How We Roll'],
#  ['This Is How We Roll'],
#  ['Die A Happy Man'],
#  ['This Is How We Roll', 'House Party'],
#  ['House Party'],
#  ['This Is How We Roll'],
#  ['This Is How We Roll', 'House Party', 'Leave The Night On'],
#  ['This Is How We Roll', 'House Party'],
#  ['Leave The Night On', 'House Party'],
#  ['This Is How We Roll', 'Leave The Night On'],
#  ['House Party'],
#  ['This Is How We Roll'],
#  ['Leave The Night On'],
#  ['This Is How We Roll'],
#  ['This Is How We Roll', 'Play It Again'],
#  ['Play It Again'],
#  ['This Is How We Roll'],
#  ['This Is How We Roll', 'Play It Again', 'Leave The Night On'],
#  ['This Is How We Roll', 'Play It Again'],
#  ['Leave The Night On', 'Play It Again'],
#  ['This Is How We Roll', 'Leave The Night On'],
#  ['Play It Again'],
#  ['This Is How We Roll'],
#  ['Leave The Night On'],
#  ['This Is How We Roll', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['This Is How We Roll'],
#  ['T-Shirt', 'Die A Happy Man', 'Play It Again'],
#  ['Die A Happy Man', 'Play It Again'],
#  ['T-Shirt', 'Play It Again'],
#  ['T-Shirt', 'Die A Happy Man'],
#  ['Play It Again'],
#  ['Die A Happy Man'],
#  ['T-Shirt'],
#  ['T-Shirt', 'Play It Again'],
#  ['Play It Again'],
#  ['T-Shirt'],
#  ['Play It Again', 'H.O.L.Y.', 'Leave The Night On'],
#  ['H.O.L.Y.', 'Play It Again'],
#  ['Leave The Night On', 'Play It Again'],
#  ['H.O.L.Y.', 'Leave The Night On'],
#  ['Play It Again'],
#  ['H.O.L.Y.'],
#  ['Leave The Night On'],
#  ['Die A Happy Man', 'H.O.L.Y.', 'Play It Again'],
#  ['H.O.L.Y.', 'Play It Again'],
#  ['Die A Happy Man', 'Play It Again'],
#  ['Die A Happy Man', 'H.O.L.Y.'],
#  ['Play It Again'],
#  ['H.O.L.Y.'],
#  ['Die A Happy Man'],
#  ['H.O.L.Y.', 'Play It Again'],
#  ['Play It Again'],
#  ['H.O.L.Y.'],
#  ['Chicken Fried', 'Play It Again'],
#  ['Play It Again'],
#  ['Chicken Fried'],
#  ['Die A Happy Man', 'Play It Again', 'House Party'],
#  ['House Party', 'Play It Again'],
#  ['Die A Happy Man', 'Play It Again'],
#  ['Die A Happy Man', 'House Party'],
#  ['Play It Again'],
#  ['House Party'],
#  ['Die A Happy Man'],
#  ['Play It Again', 'House Party'],
#  ['Play It Again'],
#  ['House Party'],
#  ['Play It Again', 'House Party', 'Leave The Night On'],
#  ['House Party', 'Play It Again'],
#  ['Leave The Night On', 'Play It Again'],
#  ['Leave The Night On', 'House Party'],
#  ['Play It Again'],
#  ['House Party'],
#  ['Leave The Night On'],
#  ['Die A Happy Man', 'Play It Again', 'Leave The Night On'],
#  ['Leave The Night On', 'Play It Again'],
#  ['Die A Happy Man', 'Play It Again'],
#  ['Die A Happy Man', 'Leave The Night On'],
#  ['Play It Again'],
#  ['Leave The Night On'],
#  ['Die A Happy Man'],
#  ['Die A Happy Man', 'Play It Again'],
#  ['Play It Again'],
#  ['Die A Happy Man'],
#  ['Play It Again'],
#  ['Play It Again', 'Leave The Night On'],
#  ['Play It Again'],
#  ['Leave The Night On'],
#  ['Die A Happy Man', 'H.O.L.Y.', 'Leave The Night On'],
#  ['H.O.L.Y.', 'Leave The Night On'],
#  ['Die A Happy Man', 'Leave The Night On'],
#  ['Die A Happy Man', 'H.O.L.Y.'],
#  ['Leave The Night On'],
#  ['H.O.L.Y.'],
#  ['Die A Happy Man'],
#  ['H.O.L.Y.', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['H.O.L.Y.'],
#  ['Die A Happy Man', 'H.O.L.Y.', 'House Party'],
#  ['H.O.L.Y.', 'House Party'],
#  ['Die A Happy Man', 'House Party'],
#  ['Die A Happy Man', 'H.O.L.Y.'],
#  ['House Party'],
#  ['H.O.L.Y.'],
#  ['Die A Happy Man'],
#  ['H.O.L.Y.', 'House Party'],
#  ['House Party'],
#  ['H.O.L.Y.'],
#  ['T-Shirt', 'H.O.L.Y.'],
#  ['H.O.L.Y.'],
#  ['T-Shirt'],
#  ['T-Shirt', 'Die A Happy Man', 'H.O.L.Y.'],
#  ['Die A Happy Man', 'H.O.L.Y.'],
#  ['T-Shirt', 'H.O.L.Y.'],
#  ['T-Shirt', 'Die A Happy Man'],
#  ['H.O.L.Y.'],
#  ['Die A Happy Man'],
#  ['T-Shirt'],
#  ['H.O.L.Y.', 'Body Like A Back Road'],
#  ['Body Like A Back Road'],
#  ['H.O.L.Y.'],
#  ['Die A Happy Man', 'H.O.L.Y.', 'Body Like A Back Road'],
#  ['H.O.L.Y.', 'Body Like A Back Road'],
#  ['Die A Happy Man', 'Body Like A Back Road'],
#  ['Die A Happy Man', 'H.O.L.Y.'],
#  ['Body Like A Back Road'],
#  ['H.O.L.Y.'],
#  ['Die A Happy Man'],
#  ['H.O.L.Y.'],
#  ['Die A Happy Man', 'H.O.L.Y.'],
#  ['H.O.L.Y.'],
#  ['Die A Happy Man'],
#  ['Chicken Fried', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['Chicken Fried'],
#  ['Chicken Fried'],
#  ['Body Like A Back Road'],
#  ['Body Like A Back Road', 'House Party'],
#  ['House Party'],
#  ['Body Like A Back Road'],
#  ['Body Like A Back Road', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['Body Like A Back Road'],
#  ['Die A Happy Man', 'Body Like A Back Road', 'Leave The Night On'],
#  ['Body Like A Back Road', 'Leave The Night On'],
#  ['Die A Happy Man', 'Leave The Night On'],
#  ['Die A Happy Man', 'Body Like A Back Road'],
#  ['Leave The Night On'],
#  ['Body Like A Back Road'],
#  ['Die A Happy Man'],
#  ['T-Shirt', 'Body Like A Back Road'],
#  ['Body Like A Back Road'],
#  ['T-Shirt'],
#  ['T-Shirt', 'Die A Happy Man', 'Body Like A Back Road'],
#  ['Die A Happy Man', 'Body Like A Back Road'],
#  ['T-Shirt', 'Body Like A Back Road'],
#  ['T-Shirt', 'Die A Happy Man'],
#  ['Body Like A Back Road'],
#  ['Die A Happy Man'],
#  ['T-Shirt'],
#  ['Die A Happy Man', 'Body Like A Back Road'],
#  ['Body Like A Back Road'],
#  ['Die A Happy Man'],
#  ['T-Shirt'],
#  ['T-Shirt', 'House Party'],
#  ['House Party'],
#  ['T-Shirt'],
#  ['T-Shirt', 'Die A Happy Man', 'House Party'],
#  ['Die A Happy Man', 'House Party'],
#  ['T-Shirt', 'House Party'],
#  ['T-Shirt', 'Die A Happy Man'],
#  ['House Party'],
#  ['Die A Happy Man'],
#  ['T-Shirt'],
#  ['T-Shirt', 'Leave The Night On'],
#  ['Leave The Night On'],
#  ['T-Shirt'],
#  ['T-Shirt', 'Die A Happy Man', 'Leave The Night On'],
#  ['Die A Happy Man', 'Leave The Night On'],
#  ['T-Shirt', 'Leave The Night On'],
#  ['T-Shirt', 'Die A Happy Man'],
#  ['Leave The Night On'],
#  ['Die A Happy Man'],
#  ['T-Shirt'],
#  ['T-Shirt', 'Die A Happy Man'],
#  ['Die A Happy Man'],
#  ['T-Shirt'],
#  ['House Party'],
#  ['House Party', 'Leave The Night On'],
#  ['House Party'],
#  ['Leave The Night On'],
#  ['Die A Happy Man', 'House Party', 'Leave The Night On'],
#  ['Leave The Night On', 'House Party'],
#  ['Die A Happy Man', 'House Party'],
#  ...]
