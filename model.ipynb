# %%
import pandas as pd

TRAIN_DATASET_PATH = "./dataset/2023_spotify_ds1.csv"
TEST_DATASET_PATH = "./dataset/2023_spotify_ds2.csv"
SONGS_DATASET_PATH = "./dataset/2023_spotify_songs.csv"

# %% [markdown]
# Input: list of songs the user likes
#
# Output: list of song recommendations

# %%
songs_dataset = pd.read_csv(SONGS_DATASET_PATH)

songs_dataset
# Out:
#             artist_name                                    track_name
# 0              Sam Hunt               Bottle It Up - Acoustic Mixtape
# 1          Ryan Gosling  City Of Stars - From "La La Land" Soundtrack
# 2           Knife Party                                       Bonfire
# 3     Avenged Sevenfold                         Welcome to the Family
# 4           Cheat Codes                                    Follow You
# ...                 ...                                           ...
# 6969         Pink Floyd                                       Hey You
# 6970          Lifehouse                                  Halfway Gone
# 6971             Eminem                               Won't Back Down
# 6972        Miley Cyrus                                           4x4
# 6973           San Holo                                       We Rise
#
# [6974 rows x 2 columns]

# %%
spotify_playlists_1 = pd.read_csv(TRAIN_DATASET_PATH).dropna()
spotify_playlists_2 = pd.read_csv(TEST_DATASET_PATH).dropna()

# %%
spotify_playlists = pd.concat([spotify_playlists_1, spotify_playlists_2], ignore_index=True).drop_duplicates()

spotify_playlists
# Out:
#                                    track_uri                  album_name  \
# 0       spotify:track:06iMqWThw4w8fTFyccvOwr             Country Grammar
# 1       spotify:track:47nm8czanMUzIqHsnr5x61             Clancy's Tavern
# 2       spotify:track:24NwBd5vZ2CK8VOQVnqdxr           Toys In The Attic
# 3       spotify:track:2WKLUgklz0VDX5bKTZ3eYD               Buy Me A Boat
# 4       spotify:track:2d48mamATjby7wgPjdrSOQ                Life Changes
# ...                                      ...                         ...
# 481646  spotify:track:3lwrebzX6n6v4zP5DOqBKc           Come Home With Me
# 481649  spotify:track:6rUcS9i07F6okIe8wujs5J  The State vs. Radric Davis
# 481651  spotify:track:0OvwzS8FX73Bw7ykMRmffU                   Rule 3:36
# 481672  spotify:track:14DwbS9OjC4E5Ar91vE787                Pain Is Love
# 481681  spotify:track:6hTcuIQa0sxrrByu9wTD7s                 Born To Run
#
#                                    album_uri        artist_name  \
# 0       spotify:album:2HWBPvQoaMFBF6krXyzpOv              Nelly
# 1       spotify:album:6fDc100UHbUvS6IuxBrKRn         Toby Keith
# 2       spotify:album:36IxIOGEBAXVozDSiVs09B          Aerosmith
# 3       spotify:album:7BYmCd8JAOHpIiHIDJwDW0       Chris Janson
# 4       spotify:album:4w5Jvreahp3yvLqc4vCr9I       Thomas Rhett
# ...                                      ...                ...
# 481646  spotify:album:39944ACXhgHs7gjXa5HehY            Cam’ron
# 481649  spotify:album:0VeraxKSlJGusnOHYGOtWq         Gucci Mane
# 481651  spotify:album:2PIXzzS8WEzv8Ws92qspEH            Ja Rule
# 481672  spotify:album:019lJMwYCbjeWxhLBQFuPn            Ja Rule
# 481681  spotify:album:43YIoHKSrEw2GJsWmhZIpu  Bruce Springsteen
#
#                                    artist_uri  duration_ms     pid  \
# 0       spotify:artist:2gBjLmx6zQnFGQJCAQpRgw       291781     115
# 1       spotify:artist:2bA6fzP0lMAQ4kz6CF61w8       223386     115
# 2       spotify:artist:7Ey4PD4MYsKc5I2dolUwbH       274133     115
# 3       spotify:artist:60gmlHZmT16wiO9GiXKYK9       179077     115
# 4       spotify:artist:6x2LnllRG5uGarZMsD4iO8       223626     115
# ...                                       ...          ...     ...
# 481646  spotify:artist:7iMvwE8qANp3aIfAGKEAwS       220960  169999
# 481649  spotify:artist:13y7CgLHjMVRMDqxdx0Xdo       246013  169999
# 481651  spotify:artist:1J2VVASYAamtQ3Bt8wGgA6       262826  169999
# 481672  spotify:artist:1J2VVASYAamtQ3Bt8wGgA6       257066  169999
# 481681  spotify:artist:3eqjTLE0HfPfh78zjh6TqT       269920  169999
#
#            track_name
# 0         Ride Wit Me
# 1        Red Solo Cup
# 2       Sweet Emotion
# 3       Buy Me A Boat
# 4         Craving You
# ...               ...
# 481646         Hey Ma
# 481649       Lemonade
# 481651   Put It On Me
# 481672   Livin' It Up
# 481681    Born to Run
#
# [369612 rows x 8 columns]

# %%
playlist_groups_df = (
    spotify_playlists
    .groupby('pid')
    .agg(
        {
            'track_uri': list,
            'track_name': list
        }
    )
    .reset_index(drop=False)
)

playlist_groups_df
# Out:
#          pid                                          track_uri  \
# 0        115  [spotify:track:06iMqWThw4w8fTFyccvOwr, spotify...
# 1        123  [spotify:track:27PmvZoffODNFW2p7ehZTQ, spotify...
# 2        124  [spotify:track:3ZAMtgYJFoHwJjFkhkXqKr, spotify...
# 3        134  [spotify:track:6ltPEsP4edATzvinHOzvk2, spotify...
# 4        161  [spotify:track:5sUlaoVcLPk2Wr695jp6dd, spotify...
# ...      ...                                                ...
# 3478  169808  [spotify:track:06iMqWThw4w8fTFyccvOwr, spotify...
# 3479  169886  [spotify:track:5dNGORzxFb5z3v7vSAFkTU, spotify...
# 3480  169931  [spotify:track:5dNGORzxFb5z3v7vSAFkTU, spotify...
# 3481  169955  [spotify:track:0iA1unTbTbDOWUSlbwJ1pS, spotify...
# 3482  169999  [spotify:track:6ltPEsP4edATzvinHOzvk2, spotify...
#
#                                              track_name
# 0     [Ride Wit Me, Red Solo Cup, Sweet Emotion, Buy...
# 1     [Don't Mind, Ride Wit Me, Dance (A$$) Remix, C...
# 2     [Dance (A$$) Remix, Weekend, Clique, Good Girl...
# 3     [Still D.R.E., Ride Wit Me, Right Round - feat...
# 4     [Bartender, Just the Way You Are, Smack That -...
# ...                                                 ...
# 3478  [Ride Wit Me, Pocketful of Sunshine, Right Rou...
# 3479  [Beachin', American Country Love Song, Who I A...
# 3480  [Beachin', American Country Love Song, It Don'...
# 3481  [It Don't Hurt Like It Used To, Fix, Hard To L...
# 3482  [Still D.R.E., Ride Wit Me, I Wanna Rock, Pour...
#
# [3483 rows x 3 columns]

# %% [markdown]
# # FPGrowth

# %%
from fpgrowth_py import fpgrowth

sample_df = playlist_groups_df
sample_df
# Out:
#          pid                                          track_uri  \
# 0        115  [spotify:track:06iMqWThw4w8fTFyccvOwr, spotify...
# 1        123  [spotify:track:27PmvZoffODNFW2p7ehZTQ, spotify...
# 2        124  [spotify:track:3ZAMtgYJFoHwJjFkhkXqKr, spotify...
# 3        134  [spotify:track:6ltPEsP4edATzvinHOzvk2, spotify...
# 4        161  [spotify:track:5sUlaoVcLPk2Wr695jp6dd, spotify...
# ...      ...                                                ...
# 3478  169808  [spotify:track:06iMqWThw4w8fTFyccvOwr, spotify...
# 3479  169886  [spotify:track:5dNGORzxFb5z3v7vSAFkTU, spotify...
# 3480  169931  [spotify:track:5dNGORzxFb5z3v7vSAFkTU, spotify...
# 3481  169955  [spotify:track:0iA1unTbTbDOWUSlbwJ1pS, spotify...
# 3482  169999  [spotify:track:6ltPEsP4edATzvinHOzvk2, spotify...
#
#                                              track_name
# 0     [Ride Wit Me, Red Solo Cup, Sweet Emotion, Buy...
# 1     [Don't Mind, Ride Wit Me, Dance (A$$) Remix, C...
# 2     [Dance (A$$) Remix, Weekend, Clique, Good Girl...
# 3     [Still D.R.E., Ride Wit Me, Right Round - feat...
# 4     [Bartender, Just the Way You Are, Smack That -...
# ...                                                 ...
# 3478  [Ride Wit Me, Pocketful of Sunshine, Right Rou...
# 3479  [Beachin', American Country Love Song, Who I A...
# 3480  [Beachin', American Country Love Song, It Don'...
# 3481  [It Don't Hurt Like It Used To, Fix, Hard To L...
# 3482  [Still D.R.E., Ride Wit Me, I Wanna Rock, Pour...
#
# [3483 rows x 3 columns]

# %%
sample = sample_df.to_dict('list')['track_name']

# %%
freq_itemset_sample, rules_sample = fpgrowth(sample, minSupRatio=0.05, minConf=0.15)

# supratio = transaction / all_transactions
# confidence = consequent / (consequent U antecedent)

# %%
from typing import Dict, List

class Preprocess():
    def __init__(self, freqItemSet, rules):
        self.freqItemSet = freqItemSet
        self.rules = rules

    def preprocess_itemset(
        self, 
        sample_list: List = None
    ) -> Dict:

        result = [
            {
                'frequent_item_sets': list(item) 
            }
            
            for item in (self.freqItemSet if not sample_list else sample_list)
        ]

        return result
    
    def preprocess_rules(
        self,
        rules: List = None
    ):
        result = [
            {
                'antecedent': list(antecedent),
                'consequent': list(consequent),
                'confidence': confidence
            }

            for antecedent, consequent, confidence in (self.rules if not rules else rules)
        ]

        return result

# %%
pre_process_entity = Preprocess(freq_itemset_sample, rules_sample)

freq_itemset = pre_process_entity.preprocess_itemset()
rules = pre_process_entity.preprocess_rules()

# %%
rules_df = pd.DataFrame(rules)
freq_itemset_df = pd.DataFrame(freq_itemset)

# %%
rules_df
# Out:
#                           antecedent                     consequent  \
# 0            [Body Like A Back Road]                  [Craving You]
# 1                      [Craving You]        [Body Like A Back Road]
# 2               [From the Ground Up]              [Die A Happy Man]
# 3                  [Die A Happy Man]           [From the Ground Up]
# 4               [Leave The Night On]              [Sippin’ On Fire]
# ...                              ...                            ...
# 13279                    [One Dance]  [Broccoli (feat. Lil Yachty)]
# 13280  [Broccoli (feat. Lil Yachty)]                       [Closer]
# 13281                       [Closer]  [Broccoli (feat. Lil Yachty)]
# 13282                      [T-Shirt]  [Broccoli (feat. Lil Yachty)]
# 13283  [Broccoli (feat. Lil Yachty)]                      [T-Shirt]
#
#        confidence
# 0        0.377083
# 1        0.866029
# 2        0.834123
# 3        0.415094
# 4        0.465608
# ...           ...
# 13279    0.504310
# 13280    0.344733
# 13281    0.349030
# 13282    0.341584
# 13283    0.377565
#
# [13284 rows x 3 columns]

# %%
song_name = 'Broccoli (feat. Lil Yachty)'

mask = freq_itemset_df['frequent_item_sets'].apply(lambda x: song_name in x)

filtered_df = freq_itemset_df[mask]

filtered_df
# Out:
#                                      frequent_item_sets
# 532               [Broccoli (feat. Lil Yachty), OOOUUU]
# 593   [Broccoli (feat. Lil Yachty), Cut It (feat. Yo...
# 704            [Broccoli (feat. Lil Yachty), Champions]
# 967   [Broccoli (feat. Lil Yachty), All Night (feat....
# 1015     [Broccoli (feat. Lil Yachty), Uber Everywhere]
# ...                                                 ...
# 3606             [Broccoli (feat. Lil Yachty), HUMBLE.]
# 3609           [Broccoli (feat. Lil Yachty), One Dance]
# 3610                      [Broccoli (feat. Lil Yachty)]
# 3611              [Broccoli (feat. Lil Yachty), Closer]
# 3612             [T-Shirt, Broccoli (feat. Lil Yachty)]
#
# [278 rows x 1 columns]

# %%
mask = rules_df['antecedent'].apply(lambda x: song_name in x)

filtered_df = rules_df[mask]

filtered_df
# Out:
#                                    antecedent  \
# 172             [Broccoli (feat. Lil Yachty)]
# 238             [Broccoli (feat. Lil Yachty)]
# 406             [Broccoli (feat. Lil Yachty)]
# 916             [Broccoli (feat. Lil Yachty)]
# 994             [Broccoli (feat. Lil Yachty)]
# ...                                       ...
# 13273  [Broccoli (feat. Lil Yachty), HUMBLE.]
# 13274           [Broccoli (feat. Lil Yachty)]
# 13278           [Broccoli (feat. Lil Yachty)]
# 13280           [Broccoli (feat. Lil Yachty)]
# 13283           [Broccoli (feat. Lil Yachty)]
#
#                              consequent  confidence
# 172                            [OOOUUU]    0.247606
# 238        [Cut It (feat. Young Dolph)]    0.257182
# 406                         [Champions]    0.239398
# 916    [All Night (feat. Knox Fortune)]    0.248974
# 994                   [Uber Everywhere]    0.294118
# ...                                 ...         ...
# 13273                         [T-Shirt]    0.540166
# 13274                         [HUMBLE.]    0.493844
# 13278                       [One Dance]    0.480164
# 13280                          [Closer]    0.344733
# 13283                         [T-Shirt]    0.377565
#
# [857 rows x 3 columns]
